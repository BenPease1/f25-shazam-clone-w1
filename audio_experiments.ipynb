# %%
import matplotlib.pyplot as plt
import IPython.display as ipd
import pandas as pd
import numpy as np
import librosa
import scipy
from pydub import AudioSegment

audio_path = "/Users/benjaminpease/Music/Downloaded Music/Dinu Lipatti - Chopin Waltzes/01 - Waltz No. 4 in F Major, Op. 34 No. 3.flac"
song = AudioSegment.from_file("/Users/benjaminpease/Music/Downloaded Music/Dinu Lipatti - Chopin Waltzes/01 - Waltz No. 4 in F Major, Op. 34 No. 3.flac")
song.export("/Users/benjaminpease/output.wav", format="wav")
# Out:
# <_io.BufferedRandom name='/Users/benjaminpease/output.wav'>

# %%
audio_path = "/Users/benjaminpease/output.wav"
ipd.Audio(audio_path)

audio, sr = librosa.load(audio_path, sr=44100, duration = 10)
plt.figure(figsize=(12, 4))
plt.plot(audio, lw=0.1)  # interpolated waveform
plt.scatter(np.arange(len(audio)), audio, s=0.005, color="red")  # individual samples
plt.title("Audio Waveform")
plt.xlabel("Sample Index")
plt.ylabel("Amplitude")
plt.show()

print("audio is digitally represented as a numpy.ndarray:")
# Out:
# audio is digitally represented as a numpy.ndarray:
# [0.         0.         0.         ... 0.15463257 0.14880371 0.1427002 ]
